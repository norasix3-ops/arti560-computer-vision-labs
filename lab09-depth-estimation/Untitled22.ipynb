# %%
import os
import certifi
os.environ['SSL_CERT_FILE'] = certifi.where()

# %%
# !git clone https://github.com/LiheYoung/Depth-Anything.git
# %cd Depth-Anything
# Out:
# fatal: destination path 'Depth-Anything' already exists and is not an empty directory.
# /content/Depth-Anything

# %%
# !pip install -r requirements.txt
# !pip install certifi
# Out:
# ...
# WARNING: typer 0.24.2 does not provide the extra 'all'
# ...

# %%
# !python run.py --encoder vits --img-path /content/image1.jfif --outdir /content/outputs_gray --pred-only --grayscale
# Out:
# config.json: 100% 111/111 [00:00<00:00, 527kB/s]
# xFormers not available
# xFormers not available
# pytorch_model.bin: 100% 99.2M/99.2M [00:04<00:00, 22.5MB/s]
# Total parameters: 24.79M
# 100% 1/1 [00:01<00:00,  1.45s/it]

# %%
# !ls /content/outputs_gray
# Out:
# image1_depth.png

# %%
from IPython.display import Image, display
display(Image(filename='/content/outputs_gray/image1_depth.png'))

# %%
# !python run.py --encoder vits --img-path /content/image2.jfif --outdir /content/outputs_color --pred-only
# Out:
# ...
# xFormers not available
# xFormers not available
# Total parameters: 24.79M
# 100% 1/1 [00:00<00:00,  1.92it/s]

# %%
# !ls /content/outputs_color
# Out:
# image2_depth.png

# %%
display(Image(filename='/content/outputs_color/image2_depth.png'))

# %%
# !python run_video.py --encoder vits --video-path /content/video.mp4 --outdir /content/outputs_video
# Out:
# xFormers not available
# xFormers not available
# Total parameters: 24.79M
# Progress 1/1, Processing /content/video.mp4

# %%
# !ls /content/outputs_video
# Out:
# video_video_depth.mp4

# %%
from google.colab import files
files.download('/content/outputs_video/video_video_depth.mp4')
